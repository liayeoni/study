# %% [markdown]
# # UK E-Commerce Data

# %% [markdown]
# ##### 이커머스 소비자 데이터를 마케팅적 측면에서 분석하고, 소비자별 상품을 추천해주는 것을 목표로함.

# %% [markdown]
# ## 1. 데이터 파악 및 전처리

# %% [markdown]
# --Requirements--

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.express as px
import plotly.io as pio

pio.templates.default = "plotly_white"

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./data.csv', encoding = 'ISO-8859-1', dtype={'CustomerID' : str})
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice CustomerID         Country
# 0        12/1/2010 8:26       2.55      17850  United Kingdom
# 1        12/1/2010 8:26       3.39      17850  United Kingdom
# 2        12/1/2010 8:26       2.75      17850  United Kingdom
# 3        12/1/2010 8:26       3.39      17850  United Kingdom
# 4        12/1/2010 8:26       3.39      17850  United Kingdom
# ...                 ...        ...        ...             ...
# 541904  12/9/2011 12:50       0.85      12680          France
# 541905  12/9/2011 12:50       2.10      12680          France
# 541906  12/9/2011 12:50       4.15      12680          France
# 541907  12/9/2011 12:50       4.15      12680          France
# 541908  12/9/2011 12:50       4.95      12680          France
#
# [541909 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  object
#  7   Country      541909 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 33.1+ MB

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# - CustomerID의 dtype을 str으로 변환
# - InvoiceDate의 dtype을 datetime으로 변환

# %% [markdown]
# ## 중복값 확인

# %%
df.duplicated().sum()
# Out:
# 5268

# %% [markdown]
# - 완전히 동일한 경우만 제외

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)
len(df)
# Out:
# 536641

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %% [markdown]
# - 고객ID와 Description값이 Null인 건 모두 drop

# %%
import copy
df_og = df.copy()
print('Before drop:',len(df))
df = df.dropna(subset=['CustomerID','Description'])
print('After drop:',len(df))
# Out:
# Before drop: 536641
# After drop: 401604

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# ## 컬럼별 데이터 확인
# - InvoiceNo : 거래 고유 번호
# - StockCode : 상품 고유 번호
# - Description : 상품명
# - Quantity : 거래 수량
# - InvoiceDate : 거래 일시
# - UnitPrice : 상품 단가
# - CustomerID : 구매자 고유 번호
# - Country : 구매 국가

# %% [markdown]
# ## InvoiceNo, CustomerID
# ------

# %%
pd.DataFrame([{
    'products' : len(df['StockCode'].value_counts()),
    'transactions' : len(df['InvoiceNo'].value_counts()),
    'customers' : len(df['CustomerID'].value_counts())
}], columns=['products','transactions','customers'], index=['quantity'])
# Out:
#           products  transactions  customers
# quantity      3684         22190       4372

# %% [markdown]
# - 여기서 cutomers는 nan값 가진 cutomers제외한 값
# - products는 StockCode로 정의

# %% [markdown]
# ## StockCode
# ------

# %%
sorted(df['StockCode'].unique(), reverse=True)
# Out:
# ['POST',
#  'PADS',
#  'M',
#  'DOT',
#  'D',
#  'CRUK',
#  'C2',
#  'BANK CHARGES',
#  '90214Z',
#  '90214Y',
#  '90214W',
#  '90214V',
#  '90214U',
#  '90214T',
#  '90214S',
#  '90214R',
#  '90214P',
#  '90214O',
#  '90214N',
#  '90214M',
#  '90214L',
#  '90214K',
#  '90214J',
#  '90214I',
#  '90214H',
#  '90214G',
#  '90214F',
#  '90214E',
#  '90214D',
#  '90214C',
#  '90214B',
#  '90214A',
#  '90212C',
#  '90212B',
#  '90211B',
#  '90211A',
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 45        536370      POST     POSTAGE         3 2010-12-01 08:45:00
# 141      C536379         D    Discount        -1 2010-12-01 09:41:00
# 386       536403      POST     POSTAGE         1 2010-12-01 11:27:00
# 1098      536527      POST     POSTAGE         1 2010-12-01 13:04:00
# 1387      536540        C2    CARRIAGE         1 2010-12-01 14:05:00
# ...          ...       ...         ...       ...                 ...
# 535955    581494      POST     POSTAGE         2 2011-12-09 10:13:00
# 536280   C581499         M      Manual        -1 2011-12-09 10:28:00
# 536462    581570      POST     POSTAGE         1 2011-12-09 11:59:00
# 536499    581574      POST     POSTAGE         2 2011-12-09 12:09:00
# 536500    581578      POST     POSTAGE         3 2011-12-09 12:16:00
#
#         UnitPrice CustomerID         Country
# 45          18.00      12583          France
# 141         27.50      14527  United Kingdom
# 386         15.00      12791     Netherlands
# 1098        18.00      12662         Germany
# 1387        50.00      14911            EIRE
# ...           ...        ...             ...
# 535955      18.00      12518         Germany
# 536280     224.69      15498  United Kingdom
# 536462      18.00      12662         Germany
# 536499      18.00      12526         Germany
# 536500      18.00      12713         Germany
#
# [1915 rows x 8 columns]

# %% [markdown]
# - Post : 배송(해외 고객)
# - Pad : 쿠션 패드?
# - M : Manual
# - Dot : dotcom postage
# - CRUK : 특정 단체에 내는 Commission이라고 추정
# - C2 : Carriage

# %% [markdown]
# ### 매출과 관련없는 StockCode행 삭제
# ----

# %%
drop_sc_list = ['POST','PADS','M','DOT','D','CRUK','C2','BANK CHARGES']
drop_sc_idx = df[df['StockCode'].isin(['POST','DOT','D','CRUK','C2','BANK CHARGES'])].index
print('Before drop:',len(df))
df.drop(drop_sc_idx, inplace=True)
print('After drop:',len(df))
# Out:
# Before drop: 401604
# After drop: 400153

# %% [markdown]
# ### StockCode와 Description맞추기
# -----

# %% [markdown]
# #### 같은 StockCode인데 describe명이 다른 경우가 많다.
# - ex) 'SET 12 COLOURING PENCILS DOILY', 'SET 12 COLOUR PENCILS DOILEY', 'SET 12 COLOURING PENCILS DOILEY'
# - 'DOILEY STORAGE TIN', 'DOILEY BISCUIT TIN',  'STORAGE TIN VINTAGE DOILY ', 'STORAGE TIN VINTAGE DOILEY
# - 'RETRO LEAVES MAGNETIC NOTEPAD', 'RETO LEAVES MAGNETIC SHOPPING LIST'  'LEAVES MAGNETIC  SHOPPING LIST', 'VINTAGE LEAF MAGNETIC NOTEPAD''

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom

# %%
# 중복되는 행들
duplicated_rows = df[df.duplicated('StockCode', keep=False)]

# 중복되는 첫 번째 행의 값을 가져옴
first_duplicated_values = duplicated_rows.drop_duplicates('StockCode').set_index('StockCode')

# 중복되는 행들의 인덱스를 가져옴
duplicated_indices = duplicated_rows.index

# 중복되는 행들의 '특정 컬럼'을 첫 번째 중복 행의 값으로 채움
df.loc[duplicated_indices, 'Description'] = df.loc[duplicated_indices, 'StockCode'].map(first_duplicated_values['Description'])

df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom

# %% [markdown]
# ### StockCode Number과 Option으로 컬럼 나누기
# -----

# %%
df.insert(2, 'StockCode_Opt', df['StockCode'].str.extract('([A-Za-z]+)'))
df.insert(2, 'StockCode_No', df['StockCode'].str.extract('(\d+)'))
df.head()
# Out:
#   InvoiceNo StockCode StockCode_No StockCode_Opt  \
# 0    536365    85123A        85123             A
# 1    536365     71053        71053           NaN
# 2    536365    84406B        84406             B
# 3    536365    84029G        84029             G
# 4    536365    84029E        84029             E
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice CustomerID         Country
# 0       2.55      17850  United Kingdom
# 1       3.39      17850  United Kingdom
# 2       2.75      17850  United Kingdom
# 3       3.39      17850  United Kingdom
# 4       3.39      17850  United Kingdom

# %% [markdown]
# - StockCode컬럼은 삭제

# %%
df.drop(['StockCode'], axis=1, inplace=True)
df
# Out:
#        InvoiceNo StockCode_No StockCode_Opt  \
# 0         536365        85123             A
# 1         536365        71053           NaN
# 2         536365        84406             B
# 3         536365        84029             G
# 4         536365        84029             E
# ...          ...          ...           ...
# 536636    581587        22613           NaN
# 536637    581587        22899           NaN
# 536638    581587        23254           NaN
# 536639    581587        23255           NaN
# 536640    581587        22138           NaN
#
#                                 Description  Quantity         InvoiceDate  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                       WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2            CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4            RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
# ...                                     ...       ...                 ...
# 536636          PACK OF 20 SPACEBOY NAPKINS        12 2011-12-09 12:50:00
# 536637         CHILDREN'S APRON DOLLY GIRL          6 2011-12-09 12:50:00
# 536638        CHILDRENS CUTLERY DOLLY GIRL          4 2011-12-09 12:50:00
# 536639      CHILDRENS CUTLERY CIRCUS PARADE         4 2011-12-09 12:50:00
# 536640        BAKING SET 9 PIECE RETROSPOT          3 2011-12-09 12:50:00
#
#         UnitPrice CustomerID         Country
# 0            2.55      17850  United Kingdom
# 1            3.39      17850  United Kingdom
# 2            2.75      17850  United Kingdom
# 3            3.39      17850  United Kingdom
# 4            3.39      17850  United Kingdom
# ...           ...        ...             ...
# 536636       0.85      12680          France
# 536637       2.10      12680          France
# 536638       4.15      12680          France
# 536639       4.15      12680          France
# 536640       4.95      12680          France
#
# [400153 rows x 9 columns]

# %% [markdown]
# ### 같은 Description이어도 다른 StockCode_No인게 있다.
# - 같은 Description인데 StockCode_No과 가격이 다른 경우가 있다. (같은 경우도 있음)
# - 즉, StockCode_No자체가 옵션을 구별해주는 경우인 듯
# - 일일이 비교가 힘드니 일단 넘어가기

# %%
des_sc = df.groupby(df['Description'])['StockCode_No'].nunique()
des_sc = pd.DataFrame(des_sc)
des_sc[des_sc['StockCode_No']>=2]
# Out:
#                                  StockCode_No
# Description
# COLOURING PENCILS BROWN TUBE                2
# COLUMBIAN CANDLE RECTANGLE                  2
# COLUMBIAN CANDLE ROUND                      2
# EAU DE NILE JEWELLED PHOTOFRAME             2
# FRENCH FLORAL CUSHION COVER                 2
# FRENCH LATTICE CUSHION COVER                2
# FROSTED WHITE BASE                          2
# PINK FAIRY CAKE CUSHION COVER               2
# PINK FLOCK GLASS CANDLEHOLDER               2
# PINK FLOWERS RABBIT EASTER                  2
# RETRO PLASTIC 70'S TRAY                     2
# RETRO PLASTIC DAISY TRAY                    2
# RETRO PLASTIC POLKA TRAY                    2
# ROUND BLUE CLOCK WITH SUCKER                2
# SQUARE CHERRY BLOSSOM CABINET               2
# WHITE BAMBOO RIBS LAMPSHADE                 2

# %%
df[df['Description']=='COLUMBIAN CANDLE RECTANGLE']['StockCode_No'].unique()
# Out:
# array(['72133', '72131'], dtype=object)

# %%
df[(df['StockCode_No']=='84665') | (df['StockCode_No']=='84666')].head()
# Out:
#        InvoiceNo StockCode_No StockCode_Opt                    Description  \
# 13803     537447        84665           NaN  SQUARE CHERRY BLOSSOM CABINET
# 30114     538872        84665           NaN  SQUARE CHERRY BLOSSOM CABINET
# 30115     538872        84666           NaN  SQUARE CHERRY BLOSSOM CABINET
# 117420    546432        84666           NaN  SQUARE CHERRY BLOSSOM CABINET
# 117421    546432        84665           NaN  SQUARE CHERRY BLOSSOM CABINET
#
#         Quantity         InvoiceDate  UnitPrice CustomerID         Country
# 13803          4 2010-12-07 09:21:00       5.95      13963  United Kingdom
# 30114          4 2010-12-14 15:13:00       5.95      13097  United Kingdom
# 30115          6 2010-12-14 15:13:00       3.95      13097  United Kingdom
# 117420         6 2011-03-14 08:21:00       3.95      14180  United Kingdom
# 117421         4 2011-03-14 08:21:00       5.95      14180  United Kingdom

# %% [markdown]
# ### 가장 많이 판매된 제품 상위 20

# %%
popular_pdt = pd.DataFrame(df.groupby(['Description'])['Quantity'].sum()).reset_index()
popular_pdt.sort_values(by='Quantity', ascending=False, inplace=True)

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Description', y='Quantity', data=popular_pdt[0:20], palette='Set3')
plt.title('Top 20 Selling Products')
plt.xlabel('Description')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## PRICE, QUANTITY

# %% [markdown]
# ------

# %% [markdown]
# #### 수량 및 가격 최소/최대값

# %%
df[['Quantity', 'UnitPrice']].describe()
# Out:
#             Quantity      UnitPrice
# count  400153.000000  400153.000000
# mean       12.222570       3.292688
# std       250.732565      67.002464
# min    -80995.000000       0.000000
# 25%         2.000000       1.250000
# 50%         5.000000       1.950000
# 75%        12.000000       3.750000
# max     80995.000000   38970.000000

# %% [markdown]
# - 수량의 최소값은 -80995, 최대는 80995
# - 가격의 최소값은 0, 최대는 38970

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 8))
sns.boxplot(x = df['Quantity'], ax=ax[0])
sns.boxplot(x = df['UnitPrice'], ax=ax[1]);

# %% [markdown]
# #### (-)수량은 어떤 의미?

# %%
df[(df['Quantity'] == -9360) | (df['Quantity'] == 9360)]
# Out:
#      InvoiceNo StockCode_No StockCode_Opt  \
# 4226   C536757        84347           NaN
#
#                               Description  Quantity         InvoiceDate  \
# 4226  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360 2010-12-02 14:23:00
#
#       UnitPrice CustomerID         Country
# 4226       0.03      15838  United Kingdom

# %%
df.sort_values(by='Quantity', ascending=True).head(5)
# Out:
#        InvoiceNo StockCode_No StockCode_Opt  \
# 535161   C581484        23843           NaN
# 61011    C541433        23166           NaN
# 4226     C536757        84347           NaN
# 158702   C550456        21108           NaN
# 158701   C550456        21175           NaN
#
#                                 Description  Quantity         InvoiceDate  \
# 535161          PAPER CRAFT , LITTLE BIRDIE    -80995 2011-12-09 09:27:00
# 61011        MEDIUM CERAMIC TOP STORAGE JAR    -74215 2011-01-18 10:17:00
# 4226    ROTATING SILVER ANGELS T-LIGHT HLDR     -9360 2010-12-02 14:23:00
# 158702   FAIRY CAKE FLANNEL ASSORTED COLOUR     -3114 2011-04-18 13:08:00
# 158701          GIN + TONIC DIET METAL SIGN     -2000 2011-04-18 13:08:00
#
#         UnitPrice CustomerID         Country
# 535161       2.08      16446  United Kingdom
# 61011        1.04      12346  United Kingdom
# 4226         0.03      15838  United Kingdom
# 158702       2.10      15749  United Kingdom
# 158701       1.85      15749  United Kingdom

# %% [markdown]
# ### iqr Outlier개수 확인

# %%
df_iqr = df.copy()
quartile1 = df_iqr['Quantity'].quantile(0.25)
quartile3 = df_iqr['Quantity'].quantile(0.75)
iqr = quartile3 - quartile1

up_limit = quartile3 + 1.5 * iqr
low_limit = quartile1 - 1.5 * iqr

low = df_iqr.loc[df_iqr['Quantity'] < low_limit, 'Quantity']
up = df_iqr.loc[df_iqr['Quantity'] > up_limit, 'Quantity']
print('up_limit', up_limit)
print('low_limit', low_limit)
print('#.up', up.nunique())
print('#.low', low.nunique())
# Out:
# up_limit 27.0
# low_limit -13.0
# #.up 275
# #.low 121

# %% [markdown]
# - InvoiceNo에 C가 붙으면 Cancel된 상품?
# - 취소 수량을 어떻게 처리해야할지 고민해보기

# %% [markdown]
# ### Total BIlls 컬럼 생성

# %%
df['Total_bills'] = df['Quantity'] * df['UnitPrice']
drop_idx = df[df['Total_bills']==0].index
df.drop(drop_idx, inplace=True)
df[df['Total_bills']<1]
# Out:
#        InvoiceNo StockCode_No StockCode_Opt                       Description  \
# 114       536381        22262           NaN             FELT EGG COSY CHICKEN
# 127       536381        22261           NaN       FELT EGG COSY WHITE RABBIT
# 128       536381        84832           NaN  ZINC WILLIE WINKIE  CANDLE STICK
# 154      C536383        35004             C   SET OF 3 COLOURED  FLYING DUCKS
# 235      C536391        22556           NaN    PLASTERS IN TIN CIRCUS PARADE
# ...          ...          ...           ...                               ...
# 536572    581580        21803           NaN    CHRISTMAS TREE STAR DECORATION
# 536573    581580        21809           NaN  CHRISTMAS HANGING TREE WITH BELL
# 536574    581580        20974           NaN       12 PENCILS SMALL TUBE SKULL
# 536578    581580        22695           NaN               WICKER WREATH SMALL
# 536586    581580        22075           NaN      6 RIBBONS ELEGANT CHRISTMAS
#
#         Quantity         InvoiceDate  UnitPrice CustomerID         Country  \
# 114            1 2010-12-01 09:41:00       0.85      15311  United Kingdom
# 127            1 2010-12-01 09:41:00       0.85      15311  United Kingdom
# 128            1 2010-12-01 09:41:00       0.85      15311  United Kingdom
# 154           -1 2010-12-01 09:49:00       4.65      15311  United Kingdom
# 235          -12 2010-12-01 10:24:00       1.65      17548  United Kingdom
# ...          ...                 ...        ...        ...             ...
# 536572         2 2011-12-09 12:20:00       0.42      12748  United Kingdom
# 536573         2 2011-12-09 12:20:00       0.39      12748  United Kingdom
# 536574         1 2011-12-09 12:20:00       0.65      12748  United Kingdom
# 536578         1 2011-12-09 12:20:00       0.59      12748  United Kingdom
# 536586         2 2011-12-09 12:20:00       0.39      12748  United Kingdom
#
#         Total_bills
# 114            0.85
# 127            0.85
# 128            0.85
# 154           -4.65
# 235          -19.80
# ...             ...
# 536572         0.84
# 536573         0.78
# 536574         0.65
# 536578         0.59
# 536586         0.78
#
# [21505 rows x 10 columns]

# %% [markdown]
# ### Price Outlier 값 확인

# %%
price_max = df.sort_values(by='UnitPrice', ascending=False)
price_max[(price_max['Description'] == 'Manual') & (price_max['StockCode_No'].isnull())]
# Out:
#        InvoiceNo StockCode_No StockCode_Opt Description  Quantity  \
# 220826   C556445          NaN             M      Manual        -1
# 171882   C551699          NaN             M      Manual        -1
# 265856   C560372          NaN             M      Manual        -1
# 418856    573080          NaN             M      Manual         1
# 418855   C573079          NaN             M      Manual        -2
# ...          ...          ...           ...         ...       ...
# 282853    561894          NaN             M      Manual        36
# 282820    561894          NaN             M      Manual         1
# 512382    580054          NaN             M      Manual         8
# 352485    567912          NaN             M      Manual        29
# 352315   C567903          NaN             M      Manual      -120
#
#                InvoiceDate  UnitPrice CustomerID         Country  Total_bills
# 220826 2011-06-10 15:31:00   38970.00      15098  United Kingdom    -38970.00
# 171882 2011-05-03 14:12:00    6930.00      16029  United Kingdom     -6930.00
# 265856 2011-07-18 12:26:00    4287.63      17448  United Kingdom     -4287.63
# 418856 2011-10-27 14:20:00    4161.06      12536          France      4161.06
# 418855 2011-10-27 14:15:00    4161.06      12536          France     -8322.12
# ...                    ...        ...        ...             ...          ...
# 282853 2011-07-31 15:00:00       0.08      14456  United Kingdom         2.88
# 282820 2011-07-31 15:00:00       0.08      14456  United Kingdom         0.08
# 512382 2011-12-01 13:08:00       0.08      18122  United Kingdom         0.64
# 352485 2011-09-22 17:07:00       0.06      15555  United Kingdom         1.74
# 352315 2011-09-22 16:29:00       0.03      16422  United Kingdom        -3.60
#
# [454 rows x 10 columns]

# %%
df[df['CustomerID']=='15098']
# Out:
#        InvoiceNo StockCode_No StockCode_Opt                 Description  \
# 220815    556442        22502           NaN  PICNIC BASKET WICKER SMALL
# 220825    556444        22502           NaN  PICNIC BASKET WICKER SMALL
# 220826   C556445          NaN             M                      Manual
# 220827    556446        22502           NaN  PICNIC BASKET WICKER SMALL
# 220837   C556448        22502           NaN  PICNIC BASKET WICKER SMALL
#
#         Quantity         InvoiceDate  UnitPrice CustomerID         Country  \
# 220815        60 2011-06-10 15:22:00       4.95      15098  United Kingdom
# 220825        60 2011-06-10 15:28:00     649.50      15098  United Kingdom
# 220826        -1 2011-06-10 15:31:00   38970.00      15098  United Kingdom
# 220827         1 2011-06-10 15:33:00     649.50      15098  United Kingdom
# 220837       -60 2011-06-10 15:39:00       4.95      15098  United Kingdom
#
#         Total_bills
# 220815        297.0
# 220825      38970.0
# 220826     -38970.0
# 220827        649.5
# 220837       -297.0

# %% [markdown]
# -
# - Outlier을 어떻게 처리할지? --> 결국 취소건을 어떻게 처리할지의 문제
# - IQR Method?& 평균값으로 대체? or Cancel 건 drop?

# %% [markdown]
# ### Transaction_Status컬럼 생성
# - 송장 번호 앞에 C가 붙은 건은 Cancel, 아니면 Complete 컬럼 생성

# %%
total_transactions = df.groupby(['CustomerID'])['InvoiceNo'].nunique().reset_index()
df['Transaction_Status'] = np.where(df['InvoiceNo'].astype(str).str.startswith('C'), 'Cancelled', 'Completed')
df.head()
# Out:
#   InvoiceNo StockCode_No StockCode_Opt                          Description  \
# 0    536365        85123             A   WHITE HANGING HEART T-LIGHT HOLDER
# 1    536365        71053           NaN                  WHITE METAL LANTERN
# 2    536365        84406             B       CREAM CUPID HEARTS COAT HANGER
# 3    536365        84029             G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4    536365        84029             E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity InvoiceMonth InvoiceTime  InvoiceWeekday         InvoiceDate  \
# 0         6      2010-12       08:26               2 2010-12-01 08:26:00
# 1         6      2010-12       08:26               2 2010-12-01 08:26:00
# 2         8      2010-12       08:26               2 2010-12-01 08:26:00
# 3         6      2010-12       08:26               2 2010-12-01 08:26:00
# 4         6      2010-12       08:26               2 2010-12-01 08:26:00
#
#    UnitPrice CustomerID         Country  Total_bills Transaction_Status
# 0       2.55      17850  United Kingdom        15.30          Completed
# 1       3.39      17850  United Kingdom        20.34          Completed
# 2       2.75      17850  United Kingdom        22.00          Completed
# 3       3.39      17850  United Kingdom        20.34          Completed
# 4       3.39      17850  United Kingdom        20.34          Completed

# %% [markdown]
# ### 지역
# ----

# %%
df['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Greece', 'Singapore', 'Lebanon',
#        'United Arab Emirates', 'Saudi Arabia', 'Czech Republic', 'Canada',
#        'Unspecified', 'Brazil', 'USA', 'European Community', 'Bahrain',
#        'Malta', 'RSA'], dtype=object)

# %% [markdown]
# ### 영국을 제외한 판매금액 높은 국가 Top 20

# %%
plt.figure(figsize=(12, 8))
df[df['Country'] != 'United Kingdom'].groupby(['Country'])['Total_bills'].sum().sort_values(ascending=False).nlargest(20).plot.bar(color='grey')
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# - 2011년 B2C 전자상거래 부문에서 2010년 가장 높은 매출을 기록한 곳은 영국, 독일, 프랑스, 스페인, 이탈리아 순
# - 전체 인구당 인터넷 사용자의 비율은 노르웨이, 네덜란드, 덴마크, 핀란드 순
# - 모바일 인터넷 보급률이 상승하며 전자상거래 시장이 확대되었던 시기이고, 그 중에서도 서유럽 국가들이 지리적으로 유리한 입지에 있어 높은 판매를 기록한 것으로 보임.
# - 2007년에 네덜란드는 이미 5000개가 넘는 온라인 스토어와 배송 업체를 보유하고 있는 국가였고 해외 플랫폼뿐만 아니라 현지 플랫폼의 사용률도 높다.
# - 출처 : https://blog.naver.com/gii_korea/150128206514
# - https://dream.kotra.or.kr/kotranews/cms/news/actionKotraBoardDetail.do?SITE_NO=3&MENU_ID=80&CONTENTS_NO=2&bbsGbn=242&bbsSn=242&pNttSn=113021
# - https://dream.kotra.or.kr/kotranews/cms/news/actionKotraBoardDetail.do?SITE_NO=3&MENU_ID=180&CONTENTS_NO=1&bbsGbn=243&bbsSn=243&pNttSn=213143

# %% [markdown]
# ### 국가별로 어떤 상품을 가장 많이 샀을까?

# %%
# 상위 20개 국가 리스트
top20_country = list(df[df['Country'] != 'United Kingdom'].groupby(['Country'])['Quantity'].sum().sort_values(ascending=False).nlargest(20).index)
# 20개국 최대 판매 상품
desc_list = []
country_list = []
total_bills_list = []
for i in top20_country:
    country_list.append(i)
    desc_list.append(df[df['Country'] == i].groupby(['Description', 'Country'])['Quantity'].sum().nlargest(1).reset_index()['Description'][0])
    total_bills_list.append(round(df[df['Country'] == i].groupby(['Description', 'Country'])['Quantity'].sum().nlargest(1).reset_index()['Quantity'][0], 2))

# %%
pd.DataFrame({'Country' : country_list,
             'Description' : desc_list,
             'Total_bills' : total_bills_list})
# Out:
#             Country                          Description  Total_bills
# 0       Netherlands                   RABBIT NIGHT LIGHT         4801
# 1              EIRE                 SMALL POPCORN HOLDER         1785
# 2           Germany  ROUND SNACK BOXES SET OF4 WOODLAND          1206
# 3            France                   RABBIT NIGHT LIGHT         3999
# 4         Australia              MINI PAINT SET VINTAGE          2916
# 5            Sweden              MINI PAINT SET VINTAGE          2916
# 6       Switzerland     PLASTERS IN TIN WOODLAND ANIMALS          636
# 7             Spain    PINK 3 PIECE POLKADOT CUTLERY SET         1089
# 8             Japan                   RABBIT NIGHT LIGHT         3401
# 9           Belgium      PACK OF 72 RETROSPOT CAKE CASES          480
# 10           Norway  SMALL FOLDING SCISSOR(POINTED EDGE)          576
# 11         Portugal                         POLKADOT PEN          240
# 12          Finland    PINK 3 PIECE POLKADOT CUTLERY SET          552
# 13  Channel Islands                         RAIN PONCHO           407
# 14          Denmark               RED  HARMONICA IN BOX           288
# 15            Italy                 FEATHER PEN,HOT PINK          240
# 16           Cyprus       HEART DECORATION PAINTED ZINC           384
# 17        Singapore         CHRISTMAS TREE PAINTED ZINC           384
# 18          Austria     SET 12 KIDS COLOUR  CHALK STICKS          288
# 19           Israel               WOODLAND CHARLOTTE BAG          120

# %% [markdown]
# ### Invoice Date
# -----
# - 월별 매출액, 분기별 매출액
# - 재구매율, 이탈율

# %%
df.insert(5, 'InvoiceWeekday', df['InvoiceDate'].dt.weekday)
df.insert(5, 'InvoiceTime', df['InvoiceDate'].dt.strftime('%H:%M'))
df.insert(5, 'InvoiceMonth', df['InvoiceDate'].dt.strftime('%Y-%m'))
df.head()
# Out:
#   InvoiceNo StockCode_No StockCode_Opt                          Description  \
# 0    536365        85123             A   WHITE HANGING HEART T-LIGHT HOLDER
# 1    536365        71053           NaN                  WHITE METAL LANTERN
# 2    536365        84406             B       CREAM CUPID HEARTS COAT HANGER
# 3    536365        84029             G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4    536365        84029             E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity InvoiceMonth InvoiceTime  InvoiceWeekday         InvoiceDate  \
# 0         6      2010-12       08:26               2 2010-12-01 08:26:00
# 1         6      2010-12       08:26               2 2010-12-01 08:26:00
# 2         8      2010-12       08:26               2 2010-12-01 08:26:00
# 3         6      2010-12       08:26               2 2010-12-01 08:26:00
# 4         6      2010-12       08:26               2 2010-12-01 08:26:00
#
#    UnitPrice CustomerID         Country  Total_bills
# 0       2.55      17850  United Kingdom        15.30
# 1       3.39      17850  United Kingdom        20.34
# 2       2.75      17850  United Kingdom        22.00
# 3       3.39      17850  United Kingdom        20.34
# 4       3.39      17850  United Kingdom        20.34

# %% [markdown]
# - df_og = cutomerID Null값 삭제 안 된 데이터 원본
# - 전체 매출 파악위해서는 해당 값도 필요

# %% [markdown]
# ### 월별 매출액, 월별 구매자수

# %%
fig = px.bar(df[df['InvoiceMonth'] != '2011-12'].groupby(['InvoiceMonth'])['Total_bills'].sum().reset_index(), x='InvoiceMonth', y='Total_bills', color='Total_bills', color_continuous_scale = 'deep', width=1000, height=500)
fig.show()

# %%
fig = px.bar(df[df['InvoiceMonth'] != '2011-12'].groupby(['InvoiceMonth'])['CustomerID'].count().reset_index(), x='InvoiceMonth', y='CustomerID', color='CustomerID', color_continuous_scale = 'RdPu', width=1000, height=500)
fig.show()

# %% [markdown]
# ### cf)해외 구매자들의 비율도 가을/겨울 시즌에 증가할 것이다.

# %%
is_uk = df.groupby(['InvoiceMonth', 'Is_UK'])[['CustomerID']].count()
is_uk['Percentage'] = is_uk.groupby(level=0)['CustomerID'].transform(lambda x : x / x.sum())
is_uk.head()
# Out:
#                     CustomerID  Percentage
# InvoiceMonth Is_UK
# 2010-12      0            2237    0.085174
#              1           24027    0.914826
# 2011-01      0            3093    0.143314
#              1           18489    0.856686
# 2011-02      0            2184    0.108857

# %%
fig = px.bar(is_uk.reset_index(), x='InvoiceMonth', y='CustomerID', color='Is_UK', barmode = 'overlay',color_discrete_sequence = [px.colors.sequential.dense[6], px.colors.sequential.dense[3]], width=1000, height=500 )
fig.show()

# %%
fig = px.bar(is_uk.reset_index(), x='InvoiceMonth', y='Percentage', color='Is_UK', color_discrete_sequence = [px.colors.sequential.dense[1], px.colors.sequential.dense[2]], width=1000, height=500 )
fig.show()

# %% [markdown]
# - 해외 구매자들의 수는 증가했지만 비율 측면에서 봤을 때 시즌별로 해외 구매자 수의 변화 패턴은 없는 것으로 보인다.

# %% [markdown]
# # 코호트 분석
# - 사용자 행동을 그룹으로 나눠 지표별로 수치화한 뒤 분석
# - 예를 들어 12월 1일세션을 시작한 사용자를 그룹으로 나누어 해당 그룹이 몇 % 재방문하였는지 비중을 알 수 있음.
# - 12월 1일 첫구매를 한 사용자 중 이후 얼마나 재구매를 하였을까?
# - 즉, 코호트 그룹 별 사용자 유지율을 확인할 수 있음.
# - 반대로 첫 구매 후 며칠 이후에 재구매율이 하락하는지 파악할 수 있음
# - https://www.beusable.net/blog/?p=4355

# %% [markdown]
# #### 첫 구매일 기준으로 코호트 그룹 분리

# %%
df_cohort = df[df['InvoiceMonth'] != '2011-12']
cohort_group = df_cohort.groupby(['CustomerID'])[['InvoiceMonth']].min()
cohort_group.rename(columns={'InvoiceMonth' : 'CohortGroup'}, inplace=True)
df_cohort = pd.merge(df_cohort, cohort_group, on ='CustomerID', how='left')
df_cohort.head()
# Out:
#   InvoiceNo StockCode_No StockCode_Opt                          Description  \
# 0    536365        85123             A   WHITE HANGING HEART T-LIGHT HOLDER
# 1    536365        71053           NaN                  WHITE METAL LANTERN
# 2    536365        84406             B       CREAM CUPID HEARTS COAT HANGER
# 3    536365        84029             G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4    536365        84029             E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity InvoiceMonth InvoiceTime  InvoiceWeekday         InvoiceDate  \
# 0         6      2010-12       08:26               2 2010-12-01 08:26:00
# 1         6      2010-12       08:26               2 2010-12-01 08:26:00
# 2         8      2010-12       08:26               2 2010-12-01 08:26:00
# 3         6      2010-12       08:26               2 2010-12-01 08:26:00
# 4         6      2010-12       08:26               2 2010-12-01 08:26:00
#
#    UnitPrice CustomerID         Country  Total_bills Transaction_Status  \
# 0       2.55      17850  United Kingdom        15.30          Completed
# 1       3.39      17850  United Kingdom        20.34          Completed
# 2       2.75      17850  United Kingdom        22.00          Completed
# 3       3.39      17850  United Kingdom        20.34          Completed
# 4       3.39      17850  United Kingdom        20.34          Completed
#
#   CohortGroup
# 0     2010-12
# 1     2010-12
# 2     2010-12
# 3     2010-12
# 4     2010-12

# %% [markdown]
# #### 코호트 그룹별 총 구매액과 평균 구매액 구하기

# %%
df_cohort = df_cohort.groupby(['CohortGroup', 'InvoiceMonth'])
df_cohort = df_cohort.agg({'CustomerID' : pd.Series.nunique, 'Total_bills':['sum', 'mean']}).reset_index()
df_cohort.columns = ['CohortGroup', 'InvoiceMonth', 'Customers', 'TotalSpending', 'AverageSpending']
df_cohort
# Out:
#    CohortGroup InvoiceMonth  Customers  TotalSpending  AverageSpending
# 0      2010-12      2010-12        947      548115.84        20.869473
# 1      2010-12      2011-01        361      269927.83        25.123588
# 2      2010-12      2011-02        315      229342.22        25.319300
# 3      2010-12      2011-03        367      299263.47        25.124966
# 4      2010-12      2011-04        340      199012.05        19.979124
# ..         ...          ...        ...            ...              ...
# 73     2011-09      2011-10         89       25344.57        10.429864
# 74     2011-09      2011-11         97       35275.22        13.206747
# 75     2011-10      2011-10        352      151683.12        13.100978
# 76     2011-10      2011-11         91       38501.51        10.851609
# 77     2011-11      2011-11        320      131270.59        12.103134
#
# [78 rows x 5 columns]

# %% [markdown]
# ### 코호트별 첫 구매월을 기준으로 얼마나 지났는지 표기

# %%
def cohort_period(df):
    df['CohortPeriod'] = np.arange(len(df)) + 1
    return df
df_cohort= df_cohort.groupby(['CohortGroup']).apply(cohort_period)
df_cohort.head()
# Out:
#               CohortGroup InvoiceMonth  Customers  TotalSpending  \
# CohortGroup
# 2010-12     0     2010-12      2010-12        947      548115.84
#             1     2010-12      2011-01        361      269927.83
#             2     2010-12      2011-02        315      229342.22
#             3     2010-12      2011-03        367      299263.47
#             4     2010-12      2011-04        340      199012.05
#
#                AverageSpending  CohortPeriod
# CohortGroup
# 2010-12     0        20.869473             1
#             1        25.123588             2
#             2        25.319300             3
#             3        25.124966             4
#             4        19.979124             5

# %%
df_cohort.reset_index(drop=True, inplace=True)
df_cohort.head()
# Out:
#   CohortGroup InvoiceMonth  Customers  TotalSpending  AverageSpending  \
# 0     2010-12      2010-12        947      548115.84        20.869473
# 1     2010-12      2011-01        361      269927.83        25.123588
# 2     2010-12      2011-02        315      229342.22        25.319300
# 3     2010-12      2011-03        367      299263.47        25.124966
# 4     2010-12      2011-04        340      199012.05        19.979124
#
#    CohortPeriod
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5

# %% [markdown]
# ### 코호트별 재구매율 시각화

# %%
cohort_pivot = df_cohort.pivot_table(index='CohortGroup', columns='CohortPeriod', values='Customers')
cohort_retention = cohort_pivot.divide(cohort_pivot[1], axis=0)
cohort_retention.loc['MEAN'] = cohort_retention.mean(axis=0)

plt.figure(figsize=(12, 8))
sns.heatmap(cohort_retention, annot=True, cmap='RdPu', fmt='.0%')
plt.show()

# %% [markdown]
# - 2010년 12월 코호트의 재방문율이 가장 높은 편이다. 12월 이전의 구매자들도 이 그룹으로 계산되었기 때문일 수도 있음)
# - 2010년 12월 방문자 수의 절반이 2011년 11월에도 방문하였음. 계절성있는 상품에 대한 수요를 나타낼 수도 있다.
# - 공통적으로 2011년 11월의 재방문율이 높은 편이다.

# %% [markdown]
# ### 코호트별 TotalSpending

# %%
cohort_pivot = df_cohort.pivot_table(index='CohortGroup', columns='CohortPeriod', values='TotalSpending')
plt.figure(figsize=(12, 8))
sns.heatmap(cohort_pivot, annot=True, cmap='GnBu', fmt='.0f')
plt.show()

# %% [markdown]
# - 2010년 12월 코호트의 총 구매액이 가장 크다. 위의 분석과 마찬가지로, 이전의 구매자들이 2010년 12월 그룹에 포함되어 값이 크게 나올 수 있다.
# - 2010/12월 코호트의 2011년 11월의 총 구매액은 2010년 12월 금액과 비슷하게 크다.

# %% [markdown]
# ### 코호트별 구매 평균 금액

# %%
cohort_pivot = df_cohort.pivot_table(index='CohortGroup', columns='CohortPeriod', values='AverageSpending')
plt.figure(figsize=(12, 8))
sns.heatmap(cohort_pivot, annot=True, cmap='BuGn', fmt='.1f')
plt.show()

# %%
cohort_spending = df_cohort.groupby(['CohortGroup'])[['AverageSpending']].mean().reset_index()
fig = px.bar(cohort_spending, x='CohortGroup', y='AverageSpending', color='AverageSpending', color_continuous_scale = 'deep', width=1200, height=600)
fig.show()

# %% [markdown]
# - 평균적으로 2010년 12월 코호트의 평균 구매액이 가장 큰 편임. 뒤로 갈수록 평균 금액이 감소하는 추세이다.

# %% [markdown]
# ### 고객별 구매 정보 정리 - 고객별 이탈 가능성 파악
# - https://chaelist.github.io/docs/kaggle/uk_ecommerce/

# %% [markdown]
# 1. 고객별 구매 내역을 월별로 정리

# %%
# 총 구매액이 0이상인 데이터
df_purchase = df[(df['Total_bills'] > 0) & (df['InvoiceMonth'] != '2011-12')]

# 월별로 구매건수의 합 피벗 테이블
df_purchase = pd.pivot_table(df_purchase, index='CustomerID', columns='InvoiceMonth', values='InvoiceNo', aggfunc = 'count')
# 값이 0이상이면 0, 아니면 X로 표현
df_purchase = df_purchase.applymap(lambda x: 'O' if x > 0 else 'X')
df_purchase.head()
# Out:
# InvoiceMonth 2010-12 2011-01 2011-02 2011-03 2011-04 2011-05 2011-06 2011-07  \
# CustomerID
# 12346              X       O       X       X       X       X       X       X
# 12347              O       O       X       X       O       X       O       X
# 12348              O       O       X       X       O       X       X       X
# 12349              X       X       X       X       X       X       X       X
# 12350              X       X       O       X       X       X       X       X
#
# InvoiceMonth 2011-08 2011-09 2011-10 2011-11
# CustomerID
# 12346              X       X       X       X
# 12347              O       X       O       X
# 12348              X       O       X       X
# 12349              X       X       X       O
# 12350              X       X       X       X

# %% [markdown]
# 2. 고객별로, 구매와 구매사이에 걸리는 평균 기간을 계산

# %%
for index in df_purchase.index:
    templist = df_purchase.loc[index].to_list()

    month_btw = []
    for i in range(12):
        if templist[i] == 'O' :
            for j in range(1, 12 - i):
                if templist[i+j] == 'O': # 첫번째 'O'와 두번째 'O'사이의 간격을 count
                    month_btw.append(j)
                    break
    if month_btw:
        month_btw_avg = sum(month_btw) / len(month_btw) # 간격의 총합 / 간격의 개수 = 평균 구매 간격

    else:
        if (df_purchase.loc[index, '2011-11']=='O') or (df_purchase.loc[index, '2011-10'] == 'O'):
            month_btw_avg = 'New Customer'
        else:
            month_btw_avg = 'Never Returned'
    df_purchase.loc[index, 'avg_month_btw_purchases'] = month_btw_avg

df_purchase.head()
# Out:
# InvoiceMonth 2010-12 2011-01 2011-02 2011-03 2011-04 2011-05 2011-06 2011-07  \
# CustomerID
# 12346              X       O       X       X       X       X       X       X
# 12347              O       O       X       X       O       X       O       X
# 12348              O       O       X       X       O       X       X       X
# 12349              X       X       X       X       X       X       X       X
# 12350              X       X       O       X       X       X       X       X
#
# InvoiceMonth 2011-08 2011-09 2011-10 2011-11 avg_month_btw_purchases
# CustomerID
# 12346              X       X       X       X          Never Returned
# 12347              O       X       O       X                     2.0
# 12348              X       O       X       X                     3.0
# 12349              X       X       X       O            New Customer
# 12350              X       X       X       X          Never Returned

# %%
never_returned = df_purchase[df_purchase['avg_month_btw_purchases']=='Never Returned'].index
len(never_returned)
# Out:
# 1100

# %% [markdown]
# - 2010.12 ~ 2011.09 중 한 번 구매하고 다시 돌아오지 않은 고객은 1100명이다.

# %%
temp = df_purchase.query("avg_month_btw_purchases not in ['Never Returned', 'New Customer']")
temp['avg_month_btw_purchases'].mean()
# Out:
# 2.8738338005460022

# %% [markdown]
# - 재구매 고객들의 평균 구매 간격은 2.87이다.

# %% [markdown]
# ### 월별 이탈율
# - 구매 이후 3개월 간 이용이 없는 이용자를 '이탈자'로 간주하고 월별 변화를 분석

# %%
customer_churn = df_purchase.copy()
customer_churn.drop('avg_month_btw_purchases', axis=1, inplace=True)
customer_churn.head()
# Out:
# InvoiceMonth 2010-12 2011-01 2011-02 2011-03 2011-04 2011-05 2011-06 2011-07  \
# CustomerID
# 12346              X       O       X       X       X       X       X       X
# 12347              O       O       X       X       O       X       O       X
# 12348              O       O       X       X       O       X       X       X
# 12349              X       X       X       X       X       X       X       X
# 12350              X       X       O       X       X       X       X       X
#
# InvoiceMonth 2011-08 2011-09 2011-10 2011-11
# CustomerID
# 12346              X       X       X       X
# 12347              O       X       O       X
# 12348              X       O       X       X
# 12349              X       X       X       O
# 12350              X       X       X       X

# %% [markdown]
# - 3개월 이내에 다시 구매한 경우, 'Returning'이라고 표기
# - 구매가 일어나지 않은 월은 'N/A'라고 표기

# %%
columns = customer_churn.columns

for index in customer_churn.index:
    usage_list = list(customer_churn.loc[index])
    for i in range(len(columns) - 3):
        if usage_list[i] == 'X':
            customer_churn.loc[index, columns[i]] = 'N/A'
        else:
            if 'O' in usage_list[i+1 : i+4]:
                customer_churn.loc[index, columns[i]] = 'Returning'
            else:
                customer_churn.loc[index, columns[i]] = 'Churn'
customer_churn.drop(['2011-09', '2011-10', '2011-11'], axis=1, inplace=True)
customer_churn.head()
# Out:
# InvoiceMonth    2010-12    2011-01 2011-02 2011-03    2011-04 2011-05  \
# CustomerID
# 12346               N/A      Churn     N/A     N/A        N/A     N/A
# 12347         Returning  Returning     N/A     N/A  Returning     N/A
# 12348         Returning  Returning     N/A     N/A      Churn     N/A
# 12349               N/A        N/A     N/A     N/A        N/A     N/A
# 12350               N/A        N/A   Churn     N/A        N/A     N/A
#
# InvoiceMonth    2011-06 2011-07    2011-08
# CustomerID
# 12346               N/A     N/A        N/A
# 12347         Returning     N/A  Returning
# 12348               N/A     N/A        N/A
# 12349               N/A     N/A        N/A
# 12350               N/A     N/A        N/A

# %%
# customer_churn = customer_churn.unstack().reset_index()
customer_churn.rename(columns={0:'ChurnFlag'}, inplace=True)
customer_churn.head()
# Out:
#   InvoiceMonth CustomerID  ChurnFlag
# 0      2010-12      12346        N/A
# 1      2010-12      12347  Returning
# 2      2010-12      12348  Returning
# 3      2010-12      12349        N/A
# 4      2010-12      12350        N/A

# %% [markdown]
# ### 월별 Churn / Returning 고객 수 및 비율을 계산

# %%
# InvoiceMonth, ChurnFlag를 기준으로 groupby ('N/A는 무시')
monthly_churn = customer_churn.query('ChurnFlag != "N/A"')
monthly_churn = monthly_churn.groupby(['InvoiceMonth', 'ChurnFlag'])[['CustomerID']].count()
monthly_churn.rename(columns={'CustomerID' : 'CustomerCount'}, inplace=True)

#월별로 Churn vs Returning 비율을 계산
monthly_churn['Percentage'] = monthly_churn.groupby(level=0)['CustomerCount'].transform(lambda x : x / x.sum())
monthly_churn.head()
# Out:
#                         CustomerCount  Percentage
# InvoiceMonth ChurnFlag
# 2010-12      Churn                357    0.403846
#              Returning            527    0.596154
# 2011-01      Churn                263    0.354926
#              Returning            478    0.645074
# 2011-02      Churn                254    0.335092

# %% [markdown]
# ### 월별 이탈율 추이

# %% [markdown]
# - 월별 재구매자수 & 이탈자수 추이

# %%
fig = px.bar(monthly_churn.reset_index(), 
             x = 'InvoiceMonth', y='CustomerCount', 
             color='ChurnFlag', 
             barmode='group', 
             category_orders = {'ChurnFlag' : ['Returning', 'Churn']},
            hover_data={'Percentage' : ':.0%'},
            color_discrete_sequence = [px.colors.sequential.RdPu[6], px.colors.sequential.RdPu[3]], width=1000, height=500)
fig.show()

# %%
fig = px.bar(monthly_churn.reset_index(),
            x='InvoiceMonth', y='Percentage', color='ChurnFlag',
            category_orders = {'ChurnFlag' : ['Returning', 'Churn']},
            color_discrete_sequence = [px.colors.sequential.RdPu[6], px.colors.sequential.RdPu[3]], width=1000, height=500)

fig.update_yaxes(tickformat = '.0%')
fig.show()

# %% [markdown]
# - 재구매자 수는 2010년 12월 이후 증가하는 추세이고, 2011년 8월 약 30% 증가하였다.
# - 이탈자수는 2011년 5월 이후 비교적 감소 추세이다.
# - 2011년 8월 재구매자 수가 가장 많고, 이탈자 수가 가장 적다.

# %% [markdown]
# ### 월별 신규 유입률

# %%
new_customer = df_purchase.copy()

# 월별 이용 내역을 바탕으로, 신규 유입 여부 정리
new_customer.drop('avg_month_btw_purchases', axis=1, inplace=True)
columns = new_customer.columns

for index in new_customer.index:
    usage_list = list(new_customer.loc[index])
    for i in range(3, len(columns)):
        if usage_list[i] == 'X':
            new_customer.loc[index, columns[i]] = 'N/A'
        else:
            if 'O' in usage_list[i-3: i]:
                new_customer.loc[index, columns[i]] = 'Returning'
            else:
                new_customer.loc[index, columns[i]] = 'New'
new_customer.drop(['2010-12', '2011-01', '2011-02'], axis=1, inplace=True)
new_customer.head()
# Out:
# InvoiceMonth 2011-03    2011-04 2011-05    2011-06 2011-07    2011-08 2011-09  \
# CustomerID
# 12346            N/A        N/A     N/A        N/A     N/A        N/A     N/A
# 12347            N/A  Returning     N/A  Returning     N/A  Returning     N/A
# 12348            N/A  Returning     N/A        N/A     N/A        N/A     New
# 12349            N/A        N/A     N/A        N/A     N/A        N/A     N/A
# 12350            N/A        N/A     N/A        N/A     N/A        N/A     N/A
#
# InvoiceMonth    2011-10 2011-11
# CustomerID
# 12346               N/A     N/A
# 12347         Returning     N/A
# 12348               N/A     N/A
# 12349               N/A     New
# 12350               N/A     N/A

# %%
# unstack & rename
new_customer = new_customer.unstack().reset_index()
new_customer.rename(columns={'level_0' : 'InvoiceMonth', 0 : 'NewFlag'}, inplace=True)

# # InvoiceMonth, NewFlag기준으로 groupby ( N/A는 무시 )
monthly_new = new_customer.query('NewFlag != "N/A"')
monthly_new = monthly_new.groupby(['InvoiceMonth', 'NewFlag'])[['CustomerID']].count()
monthly_new.rename(columns={'CustomerID' : 'CustomerCount'}, inplace=True)
monthly_new.head()

#월별로 New vs Returning 비율을 계산
monthly_new['Percentage'] = monthly_new.groupby(level=0)['CustomerCount'].transform(lambda x : x / x.sum())
monthly_new.head()
# Out:
#                         CustomerCount  Percentage
# InvoiceMonth NewFlag
# 2011-03      New                  452    0.464066
#              Returning            522    0.535934
# 2011-04      New                  361    0.422717
#              Returning            493    0.577283
# 2011-05      New                  372    0.352607

# %% [markdown]
# ### 월별 신규 유입률 추이

# %%
fig = px.bar(monthly_new.reset_index(),
            x = 'InvoiceMonth', y='CustomerCount', color='NewFlag', barmode='group',
            category_orders = {'NewFlag' : ['Returning', 'New']},
            hover_data = {'Percentage' : ':.0%'},
            color_discrete_sequence = [px.colors.sequential.Teal[0], px.colors.sequential.Teal[2]], width=1000, height=500)

fig.show()

# %%
fig = px.bar(monthly_new.reset_index(),
            x = 'InvoiceMonth', y='Percentage', color='NewFlag',
             category_orders = {'NewFlag' : ['Returning', 'New']},
            color_discrete_sequence = [px.colors.sequential.Teal[0], px.colors.sequential.Teal[2]], width=1000, height=500)

fig.update_yaxes(tickformat='.0%')
fig.show()

# %% [markdown]
# - 2011년 3월부터 8월까지 신규유입이 지속적으로 하락했다가, 9월부터 상승하는 추세이다. 계절성과의 연관성
# - 2011년 8월부터 재구매자의 수가 증가하는 추세이다.
# - 2011년 8월 재구매자의 비율이 가장 많고, 신규유입률의 수가 가장 적다.

# %% [markdown]
# ### 고객별 구매 데이터 정리 for PCA ( 총 구매액, 총수량, 총 구매 횟수, 총 취소 건수 등)

# %%
customer_df = df.groupby(['CustomerID'])['InvoiceDate'].max().reset_index()
# 데이터셋에서 가장 마지막 날짜
most_recent_date = df['InvoiceDate'].max()
customer_df['Recent_Date'] = most_recent_date
# 구매자의 가장 최근 구매 날짜
customer_df['Days_Since_Last_Purchase'] = (customer_df['Recent_Date'] - customer_df['InvoiceDate']).dt.days
customer_df.drop(['Recent_Date', 'InvoiceDate'], axis=1, inplace=True)
customer_df.reset_index()
customer_df.head()
# Out:
#   CustomerID  Days_Since_Last_Purchase
# 0      12346                       325
# 1      12347                         1
# 2      12348                        74
# 3      12349                        18
# 4      12350                       309

# %%
# 총 구매액, 총수량, 총 구매횟수
customer_gr = df.groupby(['CustomerID']).agg({'Total_bills' : 'sum', 'Quantity' : 'sum', 'InvoiceNo' : lambda x : x.nunique()}).reset_index()
# 컬럼 변경
customer_gr.columns=['CustomerID', 'TotalSpending', 'Purchase_Quantity', 'Frequency']
# 1회 구매당 구매액 = 구매력
customer_gr['Purchasing_Power'] = customer_gr['TotalSpending'] / customer_gr['Frequency']
customer_gr.head()
# Out:
#   CustomerID  TotalSpending  Purchase_Quantity  Frequency  Purchasing_Power
# 0      12346           0.00                  0          2          0.000000
# 1      12347        4310.00               2458          7        615.714286
# 2      12348        1437.24               2332          4        359.310000
# 3      12349        1457.55                630          1       1457.550000
# 4      12350         294.40                196          1        294.400000

# %%
customer_df = pd.merge(customer_df, customer_gr, on='CustomerID', how='left')
customer_df.head()
# Out:
#   CustomerID  Days_Since_Last_Purchase  TotalSpending  Purchase_Quantity  \
# 0      12346                       325           0.00                  0
# 1      12347                         1        4310.00               2458
# 2      12348                        74        1437.24               2332
# 3      12349                        18        1457.55                630
# 4      12350                       309         294.40                196
#
#    Frequency  Purchasing_Power
# 0          2          0.000000
# 1          7        615.714286
# 2          4        359.310000
# 3          1       1457.550000
# 4          1        294.400000

# %%
# 취소 건수 데이터
cancelled_transactions = df[df['Transaction_Status'] == 'Cancelled']
cacellation_frequency = cancelled_transactions.groupby(['CustomerID'])['InvoiceNo'].nunique().reset_index()
# 컬럼 이름 변경
cacellation_frequency.columns = ['CustomerID','Cancellation']
# customer_df와 병합
customer_df = pd.merge(customer_df, cacellation_frequency, on='CustomerID', how='left')
# Nan값 채우기
customer_df['Cancellation'].fillna(0, inplace=True)
customer_df.head()
# Out:
#   CustomerID  Days_Since_Last_Purchase  TotalSpending  Purchase_Quantity  \
# 0      12346                       325           0.00                  0
# 1      12347                         1        4310.00               2458
# 2      12348                        74        1437.24               2332
# 3      12349                        18        1457.55                630
# 4      12350                       309         294.40                196
#
#    Frequency  Purchasing_Power  Cancellation
# 0          2          0.000000           1.0
# 1          7        615.714286           0.0
# 2          4        359.310000           0.0
# 3          1       1457.550000           0.0
# 4          1        294.400000           0.0

# %%
# 취소 비율
customer_df['Cancellation_Ratio'] = customer_df['Cancellation'] / customer_df['Frequency']
customer_df.head()
# Out:
#   CustomerID  Days_Since_Last_Purchase  TotalSpending  Purchase_Quantity  \
# 0      12346                       325           0.00                  0
# 1      12347                         1        4310.00               2458
# 2      12348                        74        1437.24               2332
# 3      12349                        18        1457.55                630
# 4      12350                       309         294.40                196
#
#    Frequency  Purchasing_Power  Cancellation  Cancellation_Ratio
# 0          2          0.000000           1.0                 0.5
# 1          7        615.714286           0.0                 0.0
# 2          4        359.310000           0.0                 0.0
# 3          1       1457.550000           0.0                 0.0
# 4          1        294.400000           0.0                 0.0
